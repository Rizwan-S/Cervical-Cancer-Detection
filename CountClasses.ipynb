# %%
import pandas as pd 
import os
import torch
import shutil
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trainImgsPath = "/content/drive/MyDrive/Cervix Cytology Project/custom_dataset_ttv/images/train/"
testImgsPath = "/content/drive/MyDrive/Cervix Cytology Project/custom_dataset_ttv/images/test/"
valImgsPath = "/content/drive/MyDrive/Cervix Cytology Project/custom_dataset_ttv/images/val/"

csvFile = "/content/drive/MyDrive/Cervix Cytology Project/custom_dataset_ttv/classifications.csv"

# %%
df = pd.read_csv(csvFile)
df
# Out:
#        image_id                        image_filename  \
# 0           400  9ae8a4edde40219bad6303cebc672ee4.png
# 1           400  9ae8a4edde40219bad6303cebc672ee4.png
# 2           400  9ae8a4edde40219bad6303cebc672ee4.png
# 3           400  9ae8a4edde40219bad6303cebc672ee4.png
# 4           400  9ae8a4edde40219bad6303cebc672ee4.png
# ...         ...                                   ...
# 11529         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11530         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11531         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11532         1  be340ee72689dfe3f8dc9c24de6127f4.png
# 11533         1  be340ee72689dfe3f8dc9c24de6127f4.png
#
#                           image_doi  cell_id  \
# 0      10.6084/m9.figshare.12230906        1
# 1      10.6084/m9.figshare.12230906        2
# 2      10.6084/m9.figshare.12230906        3
# 3      10.6084/m9.figshare.12230906        4
# 4      10.6084/m9.figshare.12230906        5
# ...

# %%
trainImgs = os.listdir(trainImgsPath)
testImgs = os.listdir(testImgsPath)
valImgs = os.listdir(valImgsPath)

len(trainImgs), len(testImgs), len(valImgs)
# Out:
# (320, 40, 40)

# %%
trainCounts = {}
testCounts = {}
valCounts = {}

toCheck = ['SCC']

for index, row in df.iterrows():
  if(row['bethesda_system'] in toCheck):

    if(row['image_filename'] in trainImgs):
      if row['image_filename'] not in trainCounts:
         trainCounts[row['image_filename']] = 0
      trainCounts[row['image_filename']] = trainCounts[row['image_filename']] + 1

    elif(row['image_filename'] in testImgs):
      if row['image_filename'] not in testCounts:
        testCounts[row['image_filename']] = 0
      testCounts[row['image_filename']] = testCounts[row['image_filename']] + 1
    elif(row['image_filename'] in valCounts):
      if row['image_filename'] not in valCounts:
        valCounts[row['image_filename']] = 0
      valCounts[row['image_filename']] = valCounts[row['image_filename']] + 1

# %%
trainCounts
# Out:
# {'9ae8a4edde40219bad6303cebc672ee4.png': 5,
#  'ee5338ab73b4db0c88f9e9dc98aca68e.png': 26,
#  '81c4574751d0daa8c717d37e047ec234.png': 1,
#  '299abd9ed2593fa2a0bcd9ba0c73a576.png': 4,
#  'eb3f9b657f847098a227d3c826c6d19c.png': 4,
#  'c9b3f954a9d1e35591818b6c493facb9.png': 1,
#  '02c7fb946ad5c5e5f9c1e1178c21fc92.png': 2,
#  '9b77f6a1b82859bc68b26fae965564fa.png': 25,
#  '66ac6258c1215e76435accb18ec68f08.png': 3,
#  '4bdf1fe55c86e3fd82c022a744de5958.png': 3,
#  '81508bd550a84bbe5731b93048e54270.png': 2,
#  '6335a5572eb69c87a905e2086964b929.png': 1,
#  'aab4785d3320a7fd40e5ec45caf36b72.png': 5,
#  'de81ced6d8b99536da382f09b4290d70.png': 13,
#  'c7adf1972424f069b6355c500962722f.png': 5}

# %%
testCounts
# Out:
# {'dc2df7c3f88649ded343b13b9486cddf.png': 18,
#  '0cc6e576dac3046d279bba515e10a7a9.png': 15}

# %%
valCounts
# Out:
# {}

# %%
# keepInTrain = "/content/drive/MyDrive/Cervix Cytology Project/custom_dataset_ttv/images/keepInTrain/"

# %%
# import shutil

# for img in trainCounts:
#   oldPath = trainImgsPath + img
#   newPath = keepInTrain + img
#   shutil.move(oldPath, newPath)
